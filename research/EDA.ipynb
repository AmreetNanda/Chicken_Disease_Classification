# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# %pwd
# Out:
# 'c:\\Users\\Amreet\\Desktop\\Chicken Disease Classification\\research'

# %%
os.chdir(r"C:\Users\Amreet\Desktop\Chicken Disease Classification\artifacts")
# %pwd
# Out:
# 'C:\\Users\\Amreet\\Desktop\\Chicken Disease Classification\\artifacts'

# %%
dataset_df = pd.read_csv('train_data.csv')
dataset_df.head(10)
# Out:
#              images               label
# 0    salmo.1558.jpg          Salmonella
# 1    cocci.1866.jpg         Coccidiosis
# 2     cocci.171.jpg         Coccidiosis
# 3    salmo.1484.jpg          Salmonella
# 4       ncd.100.jpg  New Castle Disease
# 5     salmo.659.jpg          Salmonella
# 6    salmo.1386.jpg          Salmonella
# 7  healthy.1748.jpg             Healthy
# 8  healthy.1156.jpg             Healthy
# 9  healthy.1215.jpg             Healthy

# %%
print("Details regarding the Dataset")
dataset_df.info()
print("Shape of the Dataset -- ",dataset_df.shape)
# Out:
# Details regarding the Dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8067 entries, 0 to 8066
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   images  8067 non-null   object
#  1   label   8067 non-null   object
# dtypes: object(2)
# memory usage: 126.2+ KB
# Shape of the Dataset --  (8067, 2)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8, 5))
sns.countplot(x = dataset_df['label'], #cell_type
                     order = dataset_df['label'].value_counts().index, #label
                     palette= "Blues_d")
plt.xticks(rotation = 90) 
plt.title('Label Count',fontsize=16) 
plt.show()
print(dataset_df['label'].value_counts())
# Out:
# C:\Users\Amreet\AppData\Local\Temp\ipykernel_33976\2299366222.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = dataset_df['label'], #cell_type
# label
# Salmonella            2625
# Coccidiosis           2476
# Healthy               2404
# New Castle Disease     562
# Name: count, dtype: int64

# %%
dataset_df.label.unique()
# Out:
# array(['Salmonella', 'Coccidiosis', 'New Castle Disease', 'Healthy'],
#       dtype=object)

# %%
print(disease_df['image'].map(lambda x: x.shape))

# %%
sns.set_style("ticks")
from PIL import Image
plt.figure(figsize=(12, 9))

plt.subplot(2,2,1)
imSize1 = Image.open('C:\\Users\\Amreet\\Desktop\\Chicken Disease Classification\\artifacts\\data_ingestion\\cocci\\cocci.2.jpg')
plt.title('Image_1.jpg 600x450')
plt.imshow(imSize1)

plt.subplot(2,2,2)
img_ISIC_0024306_224x224 = imSize1.resize((224,224), Image.LANCZOS)
plt.title('Image_1.jpg 224x224')
plt.imshow(img_ISIC_0024306_224x224)

print(imSize1.mode, imSize1.format)
plt.show()
# Out:
# RGB JPEG
